# %%
import sys
sys.path.append("../..")
import numpy as np
np.set_printoptions(suppress=True)
import torch
torch.set_printoptions(sci_mode=False)
import matplotlib.pyplot as plt
import pandas as pd
import py3Dmol

from src.datamodule import ConformerDataModule
import tqdm

dm = ConformerDataModule("qm9", batch_size_train=512, num_workers=0)
# dm = ConformerDataModule("geom", batch_size_train=512, num_workers=0)

dset = dm.datasets["train"]

dset[0]
# Out:
# /tmp/ipykernel_624482/952448983.py:8: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# Molecule(coords=[19, 3], atoms=[19, 1], id=120661142, sizes=[1], moments=[1, 3], num_nodes=19)

# %%
def make_html(view, fname="input.html"):
    net = f'<img id="img_A"><script src="https://3Dmol.org/build/3Dmol-min.js"></script><script src="https://3Dmol.org/build/3Dmol.ui-min.js"></script>' + view._make_html()
    net = net.replace('viewer_{0}.render();'.format(view.uniqueid), 'viewer_{0}.render();\nvar png = viewer_{0}.pngURI();\ndocument.getElementById("img_A").src = png;'.format(view.uniqueid))

    with open(fname, "w") as f:
        f.write(net)

# %%
M = dset[20729].clone()
M.coords = M.coords * torch.tensor([-1.0, 1.0, 1.0])

arrow_len = 5.0
radius = 0.1
mid = 0.95
def add(view, M, style="mol", opacity=None):

    view = py3Dmol.view(width=1500, height=1500)
    view.addModel(M.xyzfile, "xyz")
    if style == "mol":
        style = {"stick": {"radius": 0.2}, "sphere": {"scale": 0.2}}
    elif style == "cloud":
        style = {"sphere": {"scale": 0.2}}
        if opacity is not None:
            style["sphere"]["opacity"] = opacity
    view.setStyle({"model": -1}, style)
    return view

def finish(view, xshift=0):
    view.addArrow({
                            'start': {'x':0.0, 'y':0.0, 'z':0.0},
                            'end': {'x':arrow_len, 'y':0.0, 'z':0.0},
                            'radius': radius,
                            'color':'red',
                            'mid': mid,
                            })
    view.addArrow({
                            'start': {'x':0.0, 'y':0.0, 'z':0.0},
                            'end': {'x':0.0, 'y':arrow_len, 'z':0.0},
                            'radius': radius,
                            'color':'green',
                            'mid': mid,
                            })
    view.addArrow({
                            'start': {'x':0.0, 'y':0.0, 'z':0.0},
                            'end': {'x':0.0, 'y':0.0, 'z':arrow_len},
                            'radius': radius,
                            'color':'blue',
                            'mid': mid,
                            })
    view.rotate(30, {'x': 1, 'y': -1, 'z': -.2})
    view.zoom(0.62)
    # view.zoomTo()
    view.translate(xshift, -50)
    return view

view = py3Dmol.view(width=1500, height=1500)
view = add(view, M, style="mol")
view = finish(view)
make_html(view, "mol.html")
view
# Out:
# <div id="3dmolviewer_17278312797524557"  style="position: relative; width: 1500px; height: 1500px;">
#         <p id="3dmolwarning_17278312797524557" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.4/3Dmol-min.js');
# }
#
# var viewer_17278312797524557 = null;
# var warn = document.getElementById("3dmolwarning_17278312797524557");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17278312797524557 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17278312797524557"),{backgroundColor:"white"});
# viewer_17278312797524557.zoomTo();
# 	viewer_17278312797524557.addModel("18\n\nC -2.816477 -0.760031 -0.133248\nC -1.551363 0.028776 -0.045618\nC -1.400059 1.391025 -0.102834\nN -0.079942 1.690305 0.011719\nC 0.644699 0.539775 0.150408\nC -0.249579 -0.504907 0.115182\nO 0.096324 -1.832079 0.212583\nH -0.710806 -2.352924 0.147224\nC 2.131327 0.492205 0.300066\nH 2.397506 0.361012 1.364578\nH 2.578321 1.428094 -0.049118\nO 2.708822 -0.537747 -0.464406\nH 2.178385 -1.332306 -0.319268\nH 0.315812 2.614211 -0.004992\nH -2.141965 2.155712 -0.216947\nH -2.969625 -1.355374 0.768516\nH -2.797546 -1.435354 -0.990373\nH -3.663610 -0.089467 -0.246853\n","xyz");
# 	viewer_17278312797524557.setStyle({"model": -1},{"stick": {"radius": 0.2}, "sphere": {"scale": 0.2}});
# 	viewer_17278312797524557.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 5.0, "y": 0.0, "z": 0.0}, "radius": 0.1, "color": "red", "mid": 0.95});
# 	viewer_17278312797524557.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 0.0, "y": 5.0, "z": 0.0}, "radius": 0.1, "color": "green", "mid": 0.95});
# 	viewer_17278312797524557.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 0.0, "y": 0.0, "z": 5.0}, "radius": 0.1, "color": "blue", "mid": 0.95});
# 	viewer_17278312797524557.rotate(30,{"x": 1, "y": -1, "z": -0.2});
# 	viewer_17278312797524557.zoom(0.62);
# 	viewer_17278312797524557.translate(0,-50);
# viewer_17278312797524557.render();
# });
# </script>

# %%
from src.models.flow import sample_ONB_0

seed = 11
import random
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
ONB_1 = M.ONB_4col.numpy()
ONB_0 = sample_ONB_0(ONB_1.shape, ONB_1[:, -1].reshape(-1, 1))

ONB_0 = torch.tensor(ONB_0)
ONB_1 = torch.tensor(ONB_1)

M_0 = M.clone()
M_0.coords = M.from_ONB_4col(ONB_0)

view = py3Dmol.view(width=1500, height=1500)
view = add(view, M_0, style="cloud")
# view.zoomTo()
view = finish(view, xshift=120)
make_html(view, "cloud.html")
view
# Out:
# <div id="3dmolviewer_1727831282429841"  style="position: relative; width: 1500px; height: 1500px;">
#         <p id="3dmolwarning_1727831282429841" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.4/3Dmol-min.js');
# }
#
# var viewer_1727831282429841 = null;
# var warn = document.getElementById("3dmolwarning_1727831282429841");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1727831282429841 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1727831282429841"),{backgroundColor:"white"});
# viewer_1727831282429841.zoomTo();
# 	viewer_1727831282429841.addModel("18\n\nC 2.802475 -0.621051 -0.157117\nC -1.176511 -0.124972 -0.117751\nC -0.280989 -1.091492 -0.281685\nN 0.365535 0.371142 -0.330798\nC 0.561381 1.726736 0.116265\nC -0.344770 0.447331 0.368283\nO 0.284047 0.298705 0.266341\nH -0.826996 -2.349217 -0.332715\nC -1.121651 -0.157924 0.070692\nH -3.073797 5.413602 -1.286343\nH -2.422670 -4.224335 -0.332647\nO 0.194105 -0.602711 0.109979\nH -9.266457 -3.538482 0.487871\nH 3.844138 2.698353 0.703172\nH 3.144526 -2.229182 -0.071030\nH -7.577882 3.954113 -0.785992\nH 4.383119 -1.232794 -0.277242\nH -6.109703 -0.950929 0.534339\n","xyz");
# 	viewer_1727831282429841.setStyle({"model": -1},{"sphere": {"scale": 0.2}});
# 	viewer_1727831282429841.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 5.0, "y": 0.0, "z": 0.0}, "radius": 0.1, "color": "red", "mid": 0.95});
# 	viewer_1727831282429841.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 0.0, "y": 5.0, "z": 0.0}, "radius": 0.1, "color": "green", "mid": 0.95});
# 	viewer_1727831282429841.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 0.0, "y": 0.0, "z": 5.0}, "radius": 0.1, "color": "blue", "mid": 0.95});
# 	viewer_1727831282429841.rotate(30,{"x": 1, "y": -1, "z": -0.2});
# 	viewer_1727831282429841.zoom(0.62);
# 	viewer_1727831282429841.translate(120,-50);
# viewer_1727831282429841.render();
# });
# </script>

# %%
from src.stiefel_log import Stiefel_Log_alg, Stiefel_Exp
log = Stiefel_Log_alg(ONB_0.numpy(), ONB_1.numpy())
ts = np.linspace(0.3, 0.7, 101, endpoint=True)

view = py3Dmol.view(width=1500, height=1500)

t = 0.5
ONB_t = torch.from_numpy(Stiefel_Exp(ONB_0, log * t))
opacity = 0.5
M_t = M.clone()
M_t.coords = M.from_ONB_4col(ONB_t)

view = add(view, M_t, style="cloud")

for t in ts:
    ONB_t = torch.from_numpy(Stiefel_Exp(ONB_0, log * t))
    opacity = 0.5
    M_t = M.clone()
    M_t.coords = M.from_ONB_4col(ONB_t)

    view.addModel(M_t.xyzfile, "xyz")
    style = {"sphere": {"scale": 0.2, "opacity": opacity}}
    view.setStyle({"model": -1}, style)

view = finish(view, xshift=120)
make_html(view, "cloud_traj.html")
view
# Out:
# <div id="3dmolviewer_17278312897136195"  style="position: relative; width: 1500px; height: 1500px;">
#         <p id="3dmolwarning_17278312897136195" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.4/3Dmol-min.js');
# }
#
# var viewer_17278312897136195 = null;
# var warn = document.getElementById("3dmolwarning_17278312897136195");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17278312897136195 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17278312897136195"),{backgroundColor:"white"});
# viewer_17278312897136195.zoomTo();
# 	viewer_17278312897136195.addModel("18\n\nC -0.150833 -0.799278 -0.265816\nC -2.089039 -0.112149 -0.103671\nC -1.371517 0.265698 -0.345179\nN 0.139149 1.502420 -0.259082\nC 1.096097 1.400684 0.190117\nC -0.250997 -0.273012 0.321394\nO 0.166858 -0.985414 0.367259\nH -2.015679 -2.539572 -0.078791\nC 0.563077 0.373431 0.247617\nH -2.097152 5.168343 0.323026\nH -0.447145 -1.408766 -0.338629\nO 2.538361 -0.901244 -0.153397\nH -5.122580 -3.725177 0.272136\nH 4.193305 2.811115 0.303827\nH 0.835331 -0.070052 -0.451041\nH -8.823879 2.127602 0.295526\nH 1.578203 -1.908319 -0.850548\nH -6.734305 -1.572462 0.200735\n","xyz");
# 	viewer_17278312897136195.setStyle({"model": -1},{"sphere": {"scale": 0.2}});
# 	viewer_17278312897136195.addModel("18\n\nC 1.150787 -0.765488 -0.249857\nC -1.877202 -0.139434 -0.119404\nC -1.007756 -0.310415 -0.361067\nN 0.257874 1.124408 -0.320214\nC 0.985766 1.620585 0.172317\nC -0.296872 -0.013277 0.364215\nO 0.191188 -0.468466 0.358982\nH -1.830467 -2.503858 -0.187371\nC -0.187636 0.210123 0.187001\nH -3.042246 5.913610 -0.327938\nH -1.460278 -2.645670 -0.373316\nO 1.789314 -0.862741 -0.024484\nH -7.453438 -3.967996 0.417647\nH 4.622358 2.803247 0.472218\nH 2.001035 -1.046381 -0.363414\nH -9.280054 3.167285 -0.121990\nH 3.093339 -1.806366 -0.650804\nH -6.985164 -1.578581 0.356340\n","xyz");
# 	viewer_17278312897136195.setStyle({"model": -1},{"sphere": {"scale": 0.2, "opacity": 0.5}});
# 	viewer_17278312897136195.addModel("18\n\nC
n","xyz");
# 	viewer_17278312897136195.setStyle({"model": -1},{"sphere": {"scale": 0.2, "opacity": 0.5}});
# 	viewer_17278312897136195.addModel("18\n\nC 0.998103 -0.771896 -0.253924\nC -1.914846 -0.137501 -0.118104\nC -1.058795 -0.241544 -0.362106\nN 0.244602 1.176684 -0.315013\nC 1.007227 1.599899 0.175401\nC -0.291241 -0.047649 0.360704\nO 0.187173 -0.532210 0.362333\nH -1.874844 -2.511129 -0.174493\nC -0.100141 0.233398 0.195225\nH -2.966618 5.869106 -0.247631\nH -1.351904 -2.501572 -0.371852\nO 1.896077 -0.873455 -0.038800\nH -7.213335 -3.962093 0.404201\nH 4.611425 2.806671 0.451930\nH 1.873647 -0.933947 -0.379138\nH -9.293730 3.062019 -0.068646\nH 2.933933 -1.830128 -0.677828\nH -6.990232 -1.596624 0.339041\n","xyz");
# 	viewer_17278312897136195.setStyle({"model": -1},{"sphere": {"scale": 0.2, "opacity": 0.5}});
# 	viewer_17278312897136195.addModel("18\n\nC 0.972490 -0.772896 -0.254547\nC -1.920811 -0.137140 -0.117870\nC -1.067135 -0.230029 -0.362200\nN 0.242350 1.185235 -0.314086\nC 1.010596 1.596290 0.175891\nC -0.290296 -0.053309 0.360075\nO 0.186541 -0.542816 0.362829\nH -1.881667 -2.512264 -0.172338\nC -0.085448 0.237181 0.196573\nH -2.952971 5.860468 -0.234267\nH -1.333451 -2.477390 -0.371537\nO 1.913467 -0.875081 -0.041224\nH -7.172141 -3.960500 0.401849\nH 4.608516 2.807175 0.448542\nH 1.852012 -0.915035 -0.381628\nH -9.294180 3.043915 -0.059812\nH 2.906683 -1.833773 -0.682264\nH -6.990130 -1.599139 0.336118\n","xyz");
# 	viewer_1

# %%
from src.stiefel_log import Stiefel_Log_alg, Stiefel_Exp, OT_permutation_reflection

ts = np.linspace(0.3, 0.7, 101, endpoint=True)

view = py3Dmol.view(width=1500, height=1500)

ONB_0_3col = OT_permutation_reflection(M.atoms.squeeze(-1).numpy(), ONB_0[:, :3].numpy(), ONB_1[:, :3].numpy(), 20, 500)
ONB_0_OT = torch.cat([torch.from_numpy(ONB_0_3col), ONB_1[:, 3].reshape(-1, 1)], dim=1)

view = py3Dmol.view(width=1500, height=1500)
M_0_OT = M.clone()
M_0_OT.coords = M.from_ONB_4col(ONB_0_OT)
view = add(view, M_0_OT, style="cloud")
view = finish(view)
make_html(view, "cloud_OT3.html")
view.show()

log = Stiefel_Log_alg(ONB_0_OT.numpy(), ONB_1.numpy())

t = 0.5
ONB_t = torch.from_numpy(Stiefel_Exp(ONB_0_OT, log * t))
opacity = 0.5
M_t = M.clone()
M_t.coords = M.from_ONB_4col(ONB_t)

view = add(view, M_t, style="cloud")

for t in ts:
    ONB_t = torch.from_numpy(Stiefel_Exp(ONB_0_OT, log * t))
    opacity = 0.5
    M_t = M.clone()
    M_t.coords = M.from_ONB_4col(ONB_t)

    view.addModel(M_t.xyzfile, "xyz")
    style = {"sphere": {"scale": 0.2, "opacity": opacity}}
    view.setStyle({"model": -1}, style)

view = finish(view)
make_html(view, "cloud_traj_OT3.html")
view
# Out:
# <div id="3dmolviewer_17278010904762807"  style="position: relative; width: 1500px; height: 1500px;">
#         <p id="3dmolwarning_17278010904762807" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.4/3Dmol-min.js');
# }
#
# var viewer_17278010904762807 = null;
# var warn = document.getElementById("3dmolwarning_17278010904762807");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17278010904762807 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17278010904762807"),{backgroundColor:"white"});
# viewer_17278010904762807.zoomTo();
# 	viewer_17278010904762807.addModel("18\n\nC -0.280989 -1.091492 -0.281685\nC -1.121651 -0.157924 0.070692\nC -1.176511 -0.124972 -0.117751\nN 0.365535 0.371142 -0.330798\nC 0.561381 1.726736 0.116265\nC -0.344770 0.447331 0.368283\nO 0.284047 0.298705 0.266341\nH -0.826996 -2.349217 -0.332715\nC 2.802475 -0.621051 -0.157117\nH 3.844138 2.698353 0.703172\nH 4.383119 -1.232794 -0.277242\nO 0.194105 -0.602711 0.109979\nH 3.144526 -2.229182 -0.071030\nH -3.073797 5.413602 -1.286343\nH -7.577882 3.954113 -0.785992\nH -6.109703 -0.950929 0.534339\nH -2.422670 -4.224335 -0.332647\nH -9.266457 -3.538482 0.487871\n","xyz");
# 	viewer_17278010904762807.setStyle({"model": -1},{"sphere": {"scale": 0.2}});
# 	viewer_17278010904762807.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 5.0, "y": 0.0, "z": 0.0}, "radius": 0.1, "color": "red", "mid": 0.95});
# 	viewer_17278010904762807.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 0.0, "y": 5.0, "z": 0.0}, "radius": 0.1, "color": "green", "mid": 0.95});
# 	viewer_17278010904762807.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 0.0, "y": 0.0, "z": 5.0}, "radius": 0.1, "color": "blue", "mid": 0.95});
# 	viewer_17278010904762807.rotate(30,{"x": 1, "y": -1, "z": -0.2});
# 	viewer_17278010904762807.zoom(0.62);
# 	viewer_17278010904762807.translate(0,-50);
# viewer_17278010904762807.render();
# });
# </script>
# <div id="3dmolviewer_17278010905056584"  style="position: relative; width: 1500px; height: 1500px;">
#         <p id="3dmolwarning_17278010905056584" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.4/3Dmol-min.js');
# }
#
# var viewer_17278010905056584 = null;
# var warn = document.getElementById("3dmolwarning_17278010905056584");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17278010905056584 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17278010905056584"),{backgroundColor:"white"});
# viewer_17278010905056584.zoomTo();
# 	viewer_17278010905056584.addModel("18\n\nC -1.554518 -0.965323 -0.233210\nC -1.502490 -0.097690 0.030037\nC -1.387458 0.727876 -0.147953\nN 0.232752 1.295690 -0.217995\nC 0.523527 1.301650 0.191999\nC -0.498130 -0.109794 0.315387\nO 0.076780 -0.851840 0.334244\nH -0.672069 -2.411987 -0.116372\nC 2.751032 0.102401 0.012839\nH 2.781719 2.133315 1.248446\nH 4.032745 0.114663 -0.321872\nO 1.745194 -0.979842 -0.242032\nH 3.191079 -2.212549 -0.312681\nH -1.348129 5.074267 -0.617504\nH -5.294138 3.743857 -0.435645\nH -5.417079 -0.991801 0.833821\nH -2.365253 -3.550242 -0.842830\nH -7.197834 -2.252238 0.116639\n","xyz");
# 	viewer_17278010905056584.setStyle({"model": -1},{"sphere": {"scale": 0.2}});
# 	viewer_17278010905056584.addModel("18\n\nC -1.027257 -1.036236 -0.261366\nC -1.389470 -0.126985 0.051430\nC -1.322365 0.391591 -0.146611\nN 0.321411 0.965166 -0.283619\nC 0.519582 1.530098 0.173668\nC -0.492457 0.116466 0.357337\nO 0.130088 -0.379386 0.331396\nH -0.698924 -2.409439 -0.211647\nC 2.857242 -0.170612 -0.075612\nH 3.155596 2.550864 1.067866\nH 4.322755 -0.471895 -0.345709\nO 1.160771 -0.930805 -0.105071\nH 3.294816 -2.348257 -0.237554\nH -2.018430 5.476529 -0.898273\nH -6.327916 4.015818 -0.568577\nH -5.909976 -0.898207 0.755638\nH -2.346796 -4.037475 -0.668573\nH -8.246732 -2.880862 0.278649\n","xyz");
# 	viewer_17278010905056584.setStyle({"model": -1},{"sphere": {"scale": 0.2, "opacity": 0.5}});
# 	viewer_17278010905056584.addModel("18\n\nC -1
n","xyz");
# 	viewer_17278010905056584.setStyle({"model": -1},{"sphere": {"scale": 0.2, "opacity": 0.5}});
# 	viewer_17278010905056584.addModel("18\n\nC -1.079396 -1.030052 -0.259026\nC -1.403200 -0.124453 0.049585\nC -1.330137 0.426037 -0.147369\nN 0.314379 1.001377 -0.278153\nC 0.518743 1.510363 0.176315\nC -0.496288 0.093387 0.354355\nO 0.122921 -0.426796 0.333160\nH -0.694393 -2.410810 -0.202580\nC 2.851416 -0.141577 -0.067869\nH 3.114012 2.519770 1.088680\nH 4.302575 -0.414701 -0.345842\nO 1.222440 -0.942029 -0.119349\nH 3.292169 -2.342000 -0.246619\nH -1.950596 5.452537 -0.870418\nH -6.231515 3.999617 -0.554558\nH -5.873884 -0.903820 0.766129\nH -2.345420 -4.001040 -0.688272\nH -8.154053 -2.824906 0.262873\n","xyz");
# 	viewer_17278010905056584.setStyle({"model": -1},{"sphere": {"scale": 0.2, "opacity": 0.5}});
# 	viewer_17278010905056584.addModel("18\n\nC -1.089847 -1.028786 -0.258544\nC -1.405882 -0.123937 0.049208\nC -1.331659 0.432912 -0.147503\nN 0.312919 1.008546 -0.277028\nC 0.518608 1.506326 0.176824\nC -0.496965 0.088773 0.353725\nO 0.121537 -0.436287 0.333473\nH -0.693541 -2.411051 -0.200753\nC 2.850117 -0.135805 -0.066288\nH 3.105792 2.513250 1.092776\nH 4.298299 -0.403202 -0.345801\nO 1.234703 -0.944107 -0.122194\nH 3.291437 -2.340545 -0.248394\nH -1.937056 5.447306 -0.864833\nH -6.212044 3.996077 -0.551769\nH -5.866316 -0.905056 0.768158\nH -2.345221 -3.993412 -0.692157\nH -8.135175 -2.813529 0.259701\n","xyz");
# 	viewer_17278010905056584.setStyle({"model": -1},{"sphere": {"scale": 0.2, "opacity": 0.5}});
# 	viewer_17278010905056584.addModel("18\n\nC -1.100306 -1.027511 -0.258058\nC -1.408542 -0.123418 0.048828\nC -1.333171 0.439782 -0.147632\nN 0.311441 1.015691 -0.275893\nC 0.518483 1.502260 0.177326\nC -0.497612 0.084161 0.353084\nO 0.120169 -0.445780 0.333773\nH -0.692706 -2.411281 -0.198921\nC 2.848774 -0.130046 -0.064698\nH 3.097604 2.506632 1.096849\nH 4.293942 -0.391684 -0.345737\nO 1.246941 -0.946128 -0.125036\nH 3.290638 -2.339023 -0.250156\nH -1.923525 5.441930 -0.859243\nH -6.192510 3.992437 -0.548986\nH -5.858629 -0.906331 0.770163\nH -2.345049 -3.985668 -0.696024\nH -8.116181 -2.802092 0.256523\n","xyz");
# 	viewer_172780109

# %%
# torch.save(ONB_0_OT, "ONB_0_OT.pt")

# %%
from src.stiefel_log import Stiefel_Log_alg, Stiefel_Exp, OT_permutation_reflection

ts = np.linspace(0.25, 0.75, 101, endpoint=True)

view = py3Dmol.view(width=1500, height=1500)

ONB_0_OT = torch.load("ONB_0_OT.pt")

view = py3Dmol.view(width=1500, height=1500)
M_0_OT = M.clone()
M_0_OT.coords = M.from_ONB_4col(ONB_0_OT)
view = add(view, M_0_OT, style="cloud")
view = finish(view, xshift=120)
make_html(view, "cloud_OT3.html")
view.show()

log = Stiefel_Log_alg(ONB_0_OT.numpy(), ONB_1.numpy())

t = 0.5
ONB_t = torch.from_numpy(Stiefel_Exp(ONB_0_OT, log * t))
opacity = 0.5
M_t = M.clone()
M_t.coords = M.from_ONB_4col(ONB_t)

view = add(view, M_t, style="cloud")

for t in ts:
    ONB_t = torch.from_numpy(Stiefel_Exp(ONB_0_OT, log * t))
    opacity = 0.5
    M_t = M.clone()
    M_t.coords = M.from_ONB_4col(ONB_t)

    view.addModel(M_t.xyzfile, "xyz")
    style = {"sphere": {"scale": 0.2, "opacity": opacity}}
    view.setStyle({"model": -1}, style)

view = finish(view, xshift=120)
make_html(view, "cloud_traj_OT3.html")
view
# Out:
# <div id="3dmolviewer_1727831319168871"  style="position: relative; width: 1500px; height: 1500px;">
#         <p id="3dmolwarning_1727831319168871" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.4/3Dmol-min.js');
# }
#
# var viewer_1727831319168871 = null;
# var warn = document.getElementById("3dmolwarning_1727831319168871");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1727831319168871 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1727831319168871"),{backgroundColor:"white"});
# viewer_1727831319168871.zoomTo();
# 	viewer_1727831319168871.addModel("18\n\nC -0.280989 -1.091492 -0.281685\nC -1.121651 -0.157924 0.070692\nC -1.176511 -0.124972 -0.117751\nN 0.365535 0.371142 -0.330798\nC 0.561381 1.726736 0.116265\nC -0.344770 0.447331 0.368283\nO 0.284047 0.298705 0.266341\nH -0.826996 -2.349217 -0.332715\nC 2.802475 -0.621051 -0.157117\nH 3.844138 2.698353 0.703172\nH 4.383119 -1.232794 -0.277242\nO 0.194105 -0.602711 0.109979\nH 3.144526 -2.229182 -0.071030\nH -3.073797 5.413602 -1.286343\nH -7.577882 3.954113 -0.785992\nH -6.109703 -0.950929 0.534339\nH -2.422670 -4.224335 -0.332647\nH -9.266457 -3.538482 0.487871\n","xyz");
# 	viewer_1727831319168871.setStyle({"model": -1},{"sphere": {"scale": 0.2}});
# 	viewer_1727831319168871.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 5.0, "y": 0.0, "z": 0.0}, "radius": 0.1, "color": "red", "mid": 0.95});
# 	viewer_1727831319168871.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 0.0, "y": 5.0, "z": 0.0}, "radius": 0.1, "color": "green", "mid": 0.95});
# 	viewer_1727831319168871.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 0.0, "y": 0.0, "z": 5.0}, "radius": 0.1, "color": "blue", "mid": 0.95});
# 	viewer_1727831319168871.rotate(30,{"x": 1, "y": -1, "z": -0.2});
# 	viewer_1727831319168871.zoom(0.62);
# 	viewer_1727831319168871.translate(120,-50);
# viewer_1727831319168871.render();
# });
# </script>
# <div id="3dmolviewer_17278313192342434"  style="position: relative; width: 1500px; height: 1500px;">
#         <p id="3dmolwarning_17278313192342434" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.4/3Dmol-min.js');
# }
#
# var viewer_17278313192342434 = null;
# var warn = document.getElementById("3dmolwarning_17278313192342434");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17278313192342434 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17278313192342434"),{backgroundColor:"white"});
# viewer_17278313192342434.zoomTo();
# 	viewer_17278313192342434.addModel("18\n\nC -1.554518 -0.965323 -0.233210\nC -1.502490 -0.097690 0.030037\nC -1.387458 0.727876 -0.147953\nN 0.232752 1.295690 -0.217995\nC 0.523527 1.301650 0.191999\nC -0.498130 -0.109794 0.315387\nO 0.076780 -0.851840 0.334244\nH -0.672069 -2.411987 -0.116372\nC 2.751032 0.102401 0.012839\nH 2.781719 2.133315 1.248446\nH 4.032745 0.114663 -0.321872\nO 1.745194 -0.979842 -0.242032\nH 3.191079 -2.212549 -0.312681\nH -1.348129 5.074267 -0.617504\nH -5.294138 3.743857 -0.435645\nH -5.417079 -0.991801 0.833821\nH -2.365253 -3.550242 -0.842830\nH -7.197834 -2.252238 0.116639\n","xyz");
# 	viewer_17278313192342434.setStyle({"model": -1},{"sphere": {"scale": 0.2}});
# 	viewer_17278313192342434.addModel("18\n\nC -0